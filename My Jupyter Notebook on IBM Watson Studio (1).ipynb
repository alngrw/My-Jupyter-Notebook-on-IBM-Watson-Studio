# %% [markdown]
# <h1> My Jupyter Notebook on IBM Watson Studio </h1>

# %% [markdown]
# <b>Alena </b>
# <br> occupation: analytics

# %% [markdown]
# <i>I am interested in data science because it can be useful when I do my work</i>

# %% [markdown]
# <h3>The code below finds a sum of 1, 2, 3, 4,</h3>

# %%
1+2+3+4
# Out:
# 10

# %% [markdown]
# <hr>Horizontal line</hr>
# <ul>
# <li>bulleted list</li>
# <li>bulleted list</li>
# <li>bulleted list</li>
# </ul>
# <s>Strike</s>
# <blockquote>Blockquote</blockquote>
