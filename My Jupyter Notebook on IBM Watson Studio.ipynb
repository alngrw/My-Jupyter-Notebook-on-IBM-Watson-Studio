# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b>Alena </b>
# <br> occupation: analytics

# %% [markdown]
# <i>I am interested in data science because it can be useful when I do my work</i>

# %% [markdown]
# <h3>The code below finds a sum of 1, 2, 3, 4,</h3>

# %%
1+2+3+4
# Out:
# 10

# %% [markdown]
# <hr>Horizontal line</hr>
# <ul>
# <li>hello world</li>
# <li>hello world</li>
# <li>hello world</li>
# </ul>

# %% [markdown]
# ![photo_2022-03-28_15-32-58.jpg](attachment:photo_2022-03-28_15-32-58.jpg)
